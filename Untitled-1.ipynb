# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Import data

# %% [markdown]
# #### Import from csv

# %%
data = pd.read_csv(
    "Data\EURUSD_M1.csv",
    sep=";",
    names=["time", "open", "high", "low", "close", "volume"],
    usecols=["time", "open", "high", "low", "close"],
    index_col="time",
    parse_dates=[0],
    date_format="%Y%m%d %H%M%S",
)
data.index
# Out:
# DatetimeIndex(['2016-01-03 17:00:00', '2016-01-03 17:01:00',
#                '2016-01-03 17:02:00', '2016-01-03 17:03:00',
#                '2016-01-03 17:04:00', '2016-01-03 17:05:00',
#                '2016-01-03 17:06:00', '2016-01-03 17:07:00',
#                '2016-01-03 17:08:00', '2016-01-03 17:09:00',
#                ...
#                '2025-01-31 16:49:00', '2025-01-31 16:50:00',
#                '2025-01-31 16:51:00', '2025-01-31 16:52:00',
#                '2025-01-31 16:53:00', '2025-01-31 16:54:00',
#                '2025-01-31 16:55:00', '2025-01-31 16:56:00',
#                '2025-01-31 16:57:00', '2025-01-31 16:58:00'],
#               dtype='datetime64[ns]', name='time', length=3330773, freq=None)

# %% [markdown]
# #### Reset data

# %%
df = data
df.sort_index()
# Out:
#                         open     high      low    close
# time
# 2016-01-03 17:00:00  1.08701  1.08713  1.08701  1.08713
# 2016-01-03 17:01:00  1.08712  1.08712  1.08712  1.08712
# 2016-01-03 17:02:00  1.08708  1.08722  1.08708  1.08722
# 2016-01-03 17:03:00  1.08717  1.08723  1.08717  1.08723
# 2016-01-03 17:04:00  1.08718  1.08718  1.08711  1.08711
# ...                      ...      ...      ...      ...
# 2025-01-31 16:54:00  1.03604  1.03619  1.03573  1.03580
# 2025-01-31 16:55:00  1.03579  1.03594  1.03575  1.03578
# 2025-01-31 16:56:00  1.03581  1.03582  1.03566  1.03576
# 2025-01-31 16:57:00  1.03575  1.03580  1.03571  1.03577
# 2025-01-31 16:58:00  1.03575  1.03576  1.03563  1.03576
#
# [3330773 rows x 4 columns]

# %% [markdown]
# ### Duplicates

# %% [markdown]
# #### Check for duplicates

# %%
df[df.index.duplicated(keep=False)].sort_index()
# Out:
#                         open     high      low    close
# time
# 2019-10-27 19:00:00  1.10839  1.10844  1.10836  1.10836
# 2019-10-27 19:00:00  1.10839  1.10844  1.10836  1.10836
# 2019-10-27 19:01:00  1.10837  1.10837  1.10826  1.10826
# 2019-10-27 19:01:00  1.10837  1.10837  1.10826  1.10826
# 2019-10-27 19:02:00  1.10826  1.10826  1.10822  1.10822
# ...                      ...      ...      ...      ...
# 2023-10-29 19:57:00  1.05628  1.05628  1.05624  1.05625
# 2023-10-29 19:58:00  1.05624  1.05624  1.05619  1.05619
# 2023-10-29 19:58:00  1.05624  1.05624  1.05619  1.05619
# 2023-10-29 19:59:00  1.05620  1.05625  1.05618  1.05624
# 2023-10-29 19:59:00  1.05620  1.05625  1.05618  1.05624
#
# [600 rows x 4 columns]

# %% [markdown]
# #### Delete duplicates

# %%
df = df[~df.index.duplicated(keep='first')]
df[df.index.duplicated(keep=False)].sort_index()
# Out:
# Empty DataFrame
# Columns: [open, high, low, close]
# Index: []

# %% [markdown]
# ### Missing timestamps

# %% [markdown]
# #### Check for missing timestamps

# %%
# Vygeneruj ideální časovou osu s minutovým krokem
full_index = pd.date_range(start=df.index.min(), end=df.index.max(), freq='min')

# Podmínky pro odstranění neobchodních minut (víkendy a Nový rok)
is_non_trading_time = (
    # Pátek po 17:00 až neděle do 17:00
    ((full_index.weekday == 4) & (full_index.time >= pd.to_datetime("17:00").time())) |
    (full_index.weekday == 5) |
    ((full_index.weekday == 6) & (full_index.time < pd.to_datetime("17:00").time())) |
    # Nový rok: 31.12. po 17:00 až 1.1. do 17:00
    (((full_index.month == 12) & (full_index.day == 31) & (full_index.time >= pd.to_datetime("17:00").time())) |
     ((full_index.month == 1) & (full_index.day == 1) & (full_index.time < pd.to_datetime("17:00").time()))) |
    #Vánoce: 25.12. po 03:00 až 25.12. do 17:00 
    ((full_index.month == 12) & (full_index.day == 25) & (full_index.time >= pd.to_datetime("03:00").time()) & (full_index.time <= pd.to_datetime("17:00").time()))
)

# Filtrování obchodních minut
full_index = full_index[~is_non_trading_time]

# Porovnej se skutečným indexem
missing_times = full_index.difference(df.index)
missing_df = pd.DataFrame(index=missing_times).sort_index()
missing_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [2016-01-03 17:52:00, 2016-01-03 17:57:00, 2016-01-04 17:02:00, 2016-01-14 18:46:00, 2016-01-18 14:14:00, 2016-01-18 14:22:00, 2016-01-18 14:44:00, 2016-01-18 16:43:00, 2016-01-18 17:35:00, 2016-01-18 17:40:00, 2016-01-18 17:42:00, 2016-01-18 18:54:00, 2016-01-18 19:56:00, 2016-01-24 17:56:00, 2016-01-26 17:27:00, 2016-02-07 17:19:00, 2016-02-07 17:47:00, 2016-02-07 17:55:00, 2016-02-11 17:56:00, 2016-02-16 17:51:00, 2016-02-28 17:30:00, 2016-02-28 17:34:00, 2016-02-29 17:22:00, 2016-03-02 18:44:00, 2016-03-06 17:19:00, 2016-03-06 17:22:00, 2016-03-06 17:23:00, 2016-03-07 17:12:00, 2016-03-07 17:41:00, 2016-03-08 17:06:00, 2016-03-13 17:08:00, 2016-03-13 17:09:00, 2016-03-13 17:10:00, 2016-03-13 17:12:00, 2016-03-13 17:13:00, 2016-03-13 17:14:00, 2016-03-13 17:18:00, 2016-03-13 17:19:00, 2016-03-13 17:20:00, 2016-03-13 17:23:00, 2016-03-13 17:29:00, 2016-03-13 17:38:00, 2016-03-13 17:43:00, 2016-03-13 17:44:00, 2016-03-13 23:11:00, 2016-03-20 17:12:00, 2016-03-20 17:32:00, 2016-03-20 17:43:00, 2016-03-20 18:41:00, 2016-03-20 18:42:00, 2016-03-20 18:48:00, 2016-03-22 17:06:00, 2016-03-22 17:21:00, 2016-03-23 17:37:00, 2016-03-24 17:53:00, 2016-03-24 17:56:00, 2016-03-24 18:24:00, 2016-03-24 18:43:00, 2016-03-24 18:49:00, 2016-03-24 23:19:00, 2016-03-25 00:09:00, 2016-03-25 02:48:00, 2016-03-25 04:25:00, 2016-03-25 08:00:00, 2016-03-25 08:02:00, 2016-03-25 08:06:00, 2016-03-25 09:38:00, 2016-03-25 10:46:00, 2016-03-25 11:28:00, 2016-03-25 11:35:00, 2016-03-25 12:03:00, 2016-03-25 12:06:00, 2016-03-25 12:16:00, 2016-03-25 12:22:00, 2016-03-25 12:38:00, 2016-03-25 12:46:00, 2016-03-25 12:54:00, 2016-03-25 12:55:00, 2016-03-25 13:03:00, 2016-03-25 13:21:00, 2016-03-25 13:28:00, 2016-03-25 13:29:00, 2016-03-25 14:20:00, 2016-03-25 14:27:00, 2016-03-25 14:30:00, 2016-03-25 14:32:00, 2016-03-25 14:35:00, 2016-03-25 14:37:00, 2016-03-25 14:41:00, 2016-03-25 14:50:00, 2016-03-25 15:07:00, 2016-03-25 15:15:00, 2016-03-25 15:17:00, 2016-03-25 15:53:00, 2016-03-25 16:05:00, 2016-03-25 16:27:00, 2016-03-25 16:29:00, 2016-03-25 16:37:00, 2016-03-25 16:56:00, 2016-03-27 17:01:00, ...]
#
# [69720 rows x 0 columns]

# %% [markdown]
# #### Plot missing timestamps

# %%
# Vytvoř hodinový graf chybějících hodnot
missing_df['hour'] = missing_df.index.hour
missing_df.loc[missing_df.index.dayofweek == 4]['hour'].value_counts().sort_index().plot(kind='bar', figsize=(12,6))
# Out:
# <Axes: xlabel='hour'>

# %% [markdown]
# #### Refill missing timestamps

# %%
# Přeskládej data podle nového indexu (doplní chybějící minuty)
df_full = df.reindex(full_index)
df = df_full

# %% [markdown]
# ### NaNs

# %% [markdown]
# #### Show NaNs

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [open, high, low, close, time_from_last_real_price, fill_method]
# Index: []

# %% [markdown]
# #### Gaps

# %% [markdown]
# ##### Localize gaps

# %%
""" mask = df.isna().any(axis=1)
i = 0
gaps = []

while i < len(df):
    if mask.iloc[i]:
        start = i
        while i < len(df) and mask.iloc[i]:
            i += 1
        gap = i - start
        gaps.append({
            'start': df.index[start],
            'end': df.index[i - 1],
            'length': gap
        })
    else:
        i += 1

gaps = pd.DataFrame(gaps)
gaps """
# Out:
# " mask = df.isna().any(axis=1)\ni = 0\ngaps = []\n\nwhile i < len(df):\n    if mask.iloc[i]:\n        start = i\n        while i < len(df) and mask.iloc[i]:\n            i += 1\n        gap = i - start\n        gaps.append({\n            'start': df.index[start],\n            'end': df.index[i - 1],\n            'length': gap\n        })\n    else:\n        i += 1\n\ngaps = pd.DataFrame(gaps)\ngaps "

# %%
# Najdi řádky s aspoň jedním NaN
mask = df.isna().any(axis=1).to_numpy()

# Vytvoř logickou změnu mezi True/False bloky
diff = np.diff(mask.astype(int))
starts = np.where(np.insert(diff, 0, 0) == 1)[0]
ends = np.where(np.append(diff, 0) == -1)[0]

# Ošetři případ, kdy maska začíná nebo končí True
if mask[0]:
    starts = np.insert(starts, 0, 0)
if mask[-1]:
    ends = np.append(ends, len(mask) - 1)

# Sestav dataframe s výsledky
gaps = pd.DataFrame({
    'start': df.index[starts],
    'end': df.index[ends],
    'length': ends - starts + 1
})
gaps
# Out:
#                     start                 end  length
# 0     2016-01-03 17:52:00 2016-01-03 17:52:00       1
# 1     2016-01-03 17:57:00 2016-01-03 17:57:00       1
# 2     2016-01-04 17:02:00 2016-01-04 17:02:00       1
# 3     2016-01-14 18:46:00 2016-01-14 18:46:00       1
# 4     2016-01-18 14:14:00 2016-01-18 14:14:00       1
# ...                   ...                 ...     ...
# 10789 2025-01-28 17:42:00 2025-01-28 17:42:00       1
# 10790 2025-01-29 17:03:00 2025-01-29 17:03:00       1
# 10791 2025-01-29 17:54:00 2025-01-29 17:54:00       1
# 10792 2025-01-29 17:56:00 2025-01-29 17:57:00       2
# 10793 2025-01-29 18:33:00 2025-01-29 18:33:00       1
#
# [10794 rows x 3 columns]

# %% [markdown]
# ##### Show gaps

# %%
gaps[(gaps["start"].dt.year == 2023) & (gaps["length"] == 60)]
# Out:
#                    start                 end  length
# 7459 2023-01-27 06:00:00 2023-01-27 06:59:00      60
# 7519 2023-02-19 18:00:00 2023-02-19 18:59:00      60
# 7520 2023-02-20 06:00:00 2023-02-20 06:59:00      60
# 7521 2023-02-20 08:00:00 2023-02-20 08:59:00      60
# 7522 2023-02-20 10:00:00 2023-02-20 10:59:00      60
# ...                  ...                 ...     ...
# 8589 2023-07-28 09:00:00 2023-07-28 09:59:00      60
# 8590 2023-07-28 11:00:00 2023-07-28 11:59:00      60
# 8591 2023-07-28 13:00:00 2023-07-28 13:59:00      60
# 8592 2023-07-28 15:00:00 2023-07-28 15:59:00      60
# 8962 2023-11-03 16:00:00 2023-11-03 16:59:00      60
#
# [594 rows x 3 columns]

# %% [markdown]
# #### Add Last time from last real price column

# %%
mask = df.isna().any(axis=1).to_numpy()

# Najdi začátky a konce mezer
diff = np.diff(mask.astype(int))
starts = np.where(np.insert(diff, 0, 0) == 1)[0]
ends = np.where(np.append(diff, 0) == -1)[0]

if mask[0]:
    starts = np.insert(starts, 0, 0)
if mask[-1]:
    ends = np.append(ends, len(mask) - 1)

# Inicializace sloupce
time_from_last_real = np.zeros(len(df))

# Pro každou mezeru zapiš čas od poslední reálné hodnoty
for start, end in zip(starts, ends):
    for i, idx in enumerate(range(start, end + 1)):
        time_from_last_real[idx] = i + 1  # i+1 minut od poslední známé hodnoty

df['time_from_last_real_price'] = time_from_last_real
df[df["time_from_last_real_price"] > 0]
# Out:
#                      open  high  low  close  time_from_last_real_price
# 2016-01-03 17:52:00   NaN   NaN  NaN    NaN                        1.0
# 2016-01-03 17:57:00   NaN   NaN  NaN    NaN                        1.0
# 2016-01-04 17:02:00   NaN   NaN  NaN    NaN                        1.0
# 2016-01-14 18:46:00   NaN   NaN  NaN    NaN                        1.0
# 2016-01-18 14:14:00   NaN   NaN  NaN    NaN                        1.0
# ...                   ...   ...  ...    ...                        ...
# 2025-01-29 17:03:00   NaN   NaN  NaN    NaN                        1.0
# 2025-01-29 17:54:00   NaN   NaN  NaN    NaN                        1.0
# 2025-01-29 17:56:00   NaN   NaN  NaN    NaN                        1.0
# 2025-01-29 17:57:00   NaN   NaN  NaN    NaN                        2.0
# 2025-01-29 18:33:00   NaN   NaN  NaN    NaN                        1.0
#
# [69720 rows x 5 columns]

# %% [markdown]
# #### Fill NaNs

# %%
fill_method = pd.Series("original", index=df.index, dtype='object')

# 1. Označ, co se má interpolovat
interp_blocks = gaps[gaps['length'] <= 5]
for _, row in interp_blocks.iterrows():
    fill_method.loc[row['start']:row['end']] = 'interpolate'

# 2. Označ, co se má ffillnout
ffill_blocks = gaps[(gaps['length'] > 5) & (gaps['length'] <= 60)]
for _, row in ffill_blocks.iterrows():
    fill_method.loc[row['start']:row['end']] = 'ffill'

# 3. Označ, co se má smazat
drop_blocks = gaps[gaps['length'] > 60]
for _, row in drop_blocks.iterrows():
    fill_method.loc[row['start']:row['end']] = 'drop'

# Default = original
df['fill_method'] = fill_method

# 4. Proveď akce podle označení
df_interp = df[df['fill_method'] == 'interpolate']
df_ffill = df[df['fill_method'] == 'ffill']
df_drop = df[df['fill_method'] == 'drop']
df_original = df[df['fill_method'] == 'original']

# Aplikuj interpolaci
for col in ['open', 'high', 'low', 'close']:
    df.loc[df_interp.index, col] = df[col].interpolate(method='linear')[df_interp.index]

# Aplikuj ffill (na základě předchozí hodnoty)
for col in ['open', 'high', 'low', 'close']:
    df.loc[df_ffill.index, col] = df[col].ffill()[df_ffill.index]

# Odstraň dlouhé mezery
df = df.drop(index=df_drop.index)

# %% [markdown]
# ### Extreme and invalid values

# %%
df[(df['open'] > 0) & (df['high'] > 0) & (df['low'] > 0) & (df['close'] > 0)]
# Out:
#                         open     high      low    close  is_filled
# 2016-01-03 17:00:00  1.08701  1.08713  1.08701  1.08713      False
# 2016-01-03 17:01:00  1.08712  1.08712  1.08712  1.08712      False
# 2016-01-03 17:02:00  1.08708  1.08722  1.08708  1.08722      False
# 2016-01-03 17:03:00  1.08717  1.08723  1.08717  1.08723      False
# 2016-01-03 17:04:00  1.08718  1.08718  1.08711  1.08711      False
# ...                      ...      ...      ...      ...        ...
# 2025-01-31 16:54:00  1.03604  1.03619  1.03573  1.03580      False
# 2025-01-31 16:55:00  1.03579  1.03594  1.03575  1.03578      False
# 2025-01-31 16:56:00  1.03581  1.03582  1.03566  1.03576      False
# 2025-01-31 16:57:00  1.03575  1.03580  1.03571  1.03577      False
# 2025-01-31 16:58:00  1.03575  1.03576  1.03563  1.03576      False
#
# [3412799 rows x 5 columns]

# %%
df.loc["2023-01-27 06:01"]
# Out:
# open                         1.08874
# high                         1.08893
# low                          1.08874
# close                        1.08891
# time_from_last_real_price        2.0
# fill_method                    ffill
# Name: 2023-01-27 06:01:00, dtype: object
